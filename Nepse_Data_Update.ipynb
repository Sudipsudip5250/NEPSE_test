# %% [markdown]
# # **This file will add new data and update data and git push data.**

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (4.16.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hp\appdata\roaming\python\python312\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\hp\appdata\roaming\python\python312\site-packages (from selenium) (2024.7.4)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\hp\appdata\roaming\python\python312\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import csv
import os
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import StaleElementReferenceException
import requests
from dotenv import load_dotenv
import sys

# %%
load_dotenv()
# GitHub Credentials
GITHUB_USERNAME = os.getenv("GITHUB_USERNAME")
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")
GITHUB_REPO = os.getenv("GITHUB_REPO")

IN_COLAB = 'google.colab' in sys.modules # Detect if we're in Colab
# Determine root path depending on environment
if IN_COLAB:
    root_path = "/content"
else:
    try:
        root_path = os.path.dirname(os.path.abspath(__file__)) # For local: use script location or current working directory
    except NameError:
        root_path = os.getcwd() # For interactive sessions like Jupyter

print(f"📂 Root path set to: {root_path}")
os.chdir(root_path)

# Define path to repo folder
folder_path = os.path.join(root_path, GITHUB_REPO)

# Step 1: Check if the repo folder exists and remove the remote link
if os.path.exists(folder_path):
    print("Old repository folder found!")
else:
    print("Repository folder does not exist, proceeding to clone.")
    clone_cmd = f"git clone https://github.com/Sudipsudip5250/Nepal_Stock_Data.git"
    os.system(clone_cmd)
    print("Cloned successfully!")

# Step 3: Set Git user credentials
os.chdir(folder_path)  # Move into the cloned repo
os.system("git config user.email 'you@example.com'")
os.system("git config user.name 'Your Name'")

# Step 4: Reset the remote URL
remote_cmd = f'git remote set-url origin https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO}.git'
os.system(remote_cmd)

print("Repository reset and cloned successfully!")
# Out:
# 📂 Root path set to: c:\Users\hp\Desktop\Sudip\nepse_analysis\Nepal_Stock_Data
# Old repository folder deleted successfully!
# Repository reset and cloned successfully!

# %%
# Define base directory
BASE_FOLDER = "Nepse_Data"
listed_company = "other_nepse_detail/listed_company.csv"

# GitHub raw file URL
GITHUB_RAW_URL = "https://raw.githubusercontent.com/Sudipsudip5250/Nepal_Stock_Data/main/other_nepse_detail/listed_company.csv"

# Check if the file exists
if not os.path.exists(listed_company):
    print(f"⚠ File '{listed_company}' not found! Downloading from GitHub...")

    try:
        response = requests.get(GITHUB_RAW_URL, timeout=10)
        response.raise_for_status()  # Raise error for bad responses (4xx, 5xx)

        with open(listed_company, "wb") as file:
            file.write(response.content)

        print(f"✅ Successfully downloaded '{listed_company}' from GitHub.")

    except requests.RequestException as e:
        print(f"❌ Failed to download file: {e}")
        exit(1)  # Exit script if download fails

# Read the CSV file
with open(listed_company, 'r', encoding='utf-8') as file:
    reader = list(csv.reader(file))
    categories = reader[0]
    symbols_by_category = list(zip(*reader[1:]))
print("✅ Successfully loaded symbol data.")
# Out:
# ✅ Successfully loaded symbol data.

# %%
# Configure Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless=new")  # New headless mode (recommended)
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--window-size=1920x1080")
chrome_options.add_argument("--log-level=3")
driver = webdriver.Chrome(options=chrome_options)
wait = WebDriverWait(driver, 3)

# %%
# Process each category and its symbols
for category, symbols in zip(categories, symbols_by_category):
    if not category.strip():
        continue

    category_folder = os.path.join(BASE_FOLDER, category.strip())
    os.makedirs(category_folder, exist_ok=True)

    for symbol in symbols:
        symbol = symbol.strip()
        if not symbol:
            continue

        csv_filename = os.path.join(category_folder, f"{symbol}.csv")
        url = f"https://www.sharesansar.com/company/{symbol}"
        driver.get(url)
        time.sleep(1)

        try:
            price_history_button = wait.until(EC.element_to_be_clickable((By.ID, "btn_cpricehistory")))
            price_history_button.click()
            time.sleep(1)
        except Exception as e:
            print(f"Error accessing price history for {symbol}: {e}")
            continue

        try:
            select_element = wait.until(EC.presence_of_element_located((By.NAME, "myTableCPriceHistory_length")))
            Select(select_element).select_by_value("50")
            time.sleep(1)
        except Exception as e:
            print(f"Failed to change display option for {symbol}: {e}")
            continue

        # Determine the latest date already present (if any)
        latest_date = None
        if os.path.exists(csv_filename):
            try:
                existing_df = pd.read_csv(csv_filename, encoding="utf-8")
                latest_date = existing_df["Date"].astype(str).max()
                print(f"📌 {symbol}: Latest data in CSV is from {latest_date}")
            except Exception as e:
                print(f"Error reading {csv_filename}: {e}")

        new_data = []
        page_count = 0
        stop_scraping = False

        # Loop until the "Next" button is disabled or no longer available
        while True:
            page_count += 1
            print(f"Scraping {symbol} - processing page {page_count}")
            try:
                # Re-locate the table on each page to avoid stale element reference
                table = wait.until(EC.presence_of_element_located((By.XPATH, "//div[@id='cpricehistory']//table")))
                rows = table.find_elements(By.XPATH, ".//tbody/tr")

                # Iterate through rows and extract data
                for row in rows:
                    # Re-locate cells within each row
                    cells = row.find_elements(By.TAG_NAME, "td")
                    if len(cells) < 9:
                        continue

                    data = [cell.text.strip() for cell in cells]
                    row_date = data[1]

                    # If we already have data and this row is not new, flag to stop scraping further pages
                    if latest_date and row_date <= latest_date:
                        stop_scraping = True
                        break
                    new_data.append(data)

            except Exception as e:
                print(f"No table found for {symbol}: {e}")
                break

            if stop_scraping:
                print(f"Stopping further scraping for {symbol} as older data encountered.")
                break

            # Try to find and click the "Next" button; if not available or disabled, break the loop
            try:
                next_button = driver.find_element(By.XPATH, "//a[contains(text(),'Next')]")
                if "disabled" in next_button.get_attribute("class").lower():
                    print("Next button is disabled. Reached last page.")
                    break
                next_button.click()
                time.sleep(1)  # You might need to adjust the wait time
            except Exception:
                print("No 'Next' button found or an error occurred. Ending pagination.")
                break

        if new_data:
            new_df = pd.DataFrame(new_data, columns=["S.N.", "Date", "Open", "High", "Low", "Ltp", "% Change", "Qty", "Turnover"])
            latest_scraped_date = new_df["Date"].max()  # Get the latest date from new data

            if os.path.exists(csv_filename):
                updated_df = pd.concat([new_df, existing_df], ignore_index=True)
            else:
                updated_df = new_df

            # Optional: convert Date column to datetime and sort (adjust ascending/descending as needed)
            updated_df["Date"] = pd.to_datetime(updated_df["Date"], format="%Y-%m-%d", errors="coerce")
            # Sort so that the newest dates appear first; change ascending=True for oldest-first
            updated_df = updated_df.sort_values(by="Date", ascending=False).reset_index(drop=True)
            # Reassign S.N. sequentially starting from 1
            updated_df["S.N."] = updated_df.index + 1
            # Rearrange columns to place S.N. first
            cols = ["S.N.", "Date", "Open", "High", "Low", "Ltp", "% Change", "Qty", "Turnover"]
            updated_df = updated_df[cols]

            # Save updated CSV file
            updated_df.to_csv(csv_filename, index=False, encoding='utf-8')
            print(f"✅ New data added for {symbol} in {csv_filename}")

            # Git Add, Commit, and Push with latest scraped date
            print(os.system("git add --all"))
            commit_message = f'Updated {symbol} data up to {latest_scraped_date}' if latest_scraped_date else f'Updated {symbol} data'
            print(os.system(f'git commit -m "{commit_message}" --allow-empty'))
            # print(os.system("git push origin main"))
            print("\n")
        else:
            print(f"⚠ No new data found for {symbol}. Skipping update.")
    print(os.system("git push origin main"))
# Out:
# 📌 CZBIL: Latest data in CSV is from 2025-04-07
# Scraping CZBIL - processing page 1
# Stopping further scraping for CZBIL as older data encountered.
# ✅ New data added for CZBIL in Nepse_Data/Commercial_Banks/CZBIL.csv
# 0
# 0
#
#
# 📌 EBL: Latest data in CSV is from 2025-04-07
# Scraping EBL - processing page 1
# Stopping further scraping for EBL as older data encountered.
# ✅ New data added for EBL in Nepse_Data/Commercial_Banks/EBL.csv
# 0
# 0
#
#
# 📌 GBIME: Latest data in CSV is from 2025-04-07
# Scraping GBIME - processing page 1
# Stopping further scraping for GBIME as older data encountered.
# ✅ New data added for GBIME in Nepse_Data/Commercial_Banks/GBIME.csv
# 0
# 0
#
#
# 📌 HBL: Latest data in CSV is from 2025-04-07
# Scraping HBL - processing page 1
# Stopping further scraping for HBL as older data encountered.
# ✅ New data added for HBL in Nepse_Data/Commercial_Banks/HBL.csv
# 0
# 0
#
#
# 📌 KBL: Latest data in CSV is from 2025-04-07
# Scraping KBL - processing page 1
# Stopping further scraping for KBL as older data encountered.
# ✅ New data added for KBL in Nepse_Data/Commercial_Banks/KBL.csv
# 0
# 0
#
#
# 📌 LSL: Latest data in CSV is from 2025-04-07
# Scraping LSL - processing page 1
# Stopping further scraping for LSL as older data encountered.
# ✅ New data added for LSL in Nepse_Data/Commercial_Banks/LSL.csv
# 0
# 0
#
#
# 📌 MBL: Latest data in CSV is from 2025-04-07
# Scraping MBL - processing page 1
# Stopping further scraping for MBL as older data encountered.
# ✅ New data added for MBL in Nepse_Data/Commercial_Banks/MBL.csv
# 0
# 0
#
#
# 📌 NABIL: Latest data in CSV is from 2025-04-07
# Scraping NABIL - processing page 1
# Stopping further scraping for NABIL as older data encountered.
# ✅ New data added for NABIL in Nepse_Data/Commercial_Banks/NABIL.csv
# 0
# 0
#
#
# 📌 NBL: Latest data in CSV is from 2025-04-07
# Scraping NBL - processing page 1
# Stopping further scraping for NBL as older data encountered.
# ✅ New data added for NBL in Nepse_Data/Commercial_Banks/NBL.csv
# 0
# 0
#
#
# 📌 NICA: Latest data in CSV is from 2025-04-07
# Scraping NICA - processing page 1
# Stopping further scraping for NICA as older data encountered.
# ✅ New data added for NICA in Nepse_Data/Commercial_Banks/NICA.csv
# 0
# 0
#
#
# 📌 NIMB: Latest data in CSV is from 2025-04-07
# Scraping NIMB - processing page 1
# Stopping further scraping for NIMB as older data encountered.
# ✅ New data added for NIMB in Nepse_Data/Commercial_Banks/NIMB.csv
# 0
# 0
#
#
# 📌 NMB: Latest data in CSV is from 2025-04-07
# Scraping NMB - processing page 1
# Stopping further scraping for NMB as older data encountered.
# ✅ New data added for NMB in Nepse_Data/Commercial_Banks/NMB.csv
# 0
# 0
#
#
# 📌 PCBL: Latest data in CSV is from 2025-04-07
# Scraping PCBL - processing page 1
# Stopping further scraping for PCBL as older data encountered.
# ✅ New data added for PCBL in Nepse_Data/Commercial_Banks/PCBL.csv
# 0
# 0
#
#
# 📌 PRVU: Latest data in CSV is from 2025-04-07
# Scraping PRVU - processing page 1
# Stopping further scraping for PRVU as older data encountered.
# ✅ New data added for PRVU in Nepse_Data/Commercial_Banks/PRVU.csv
# 0
# 0
#
#
# Error accessing price history for RBB: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 SANIMA: Latest data in CSV is from 2025-04-07
# Scraping SANIMA - processing page 1
# Stopping further scraping for SANIMA as older data encountered.
# ✅ New data added for SANIMA in Nepse_Data/Commercial_Banks/SANIMA.csv
# 0
# 0
#
#
# 📌 SBI: Latest data in CSV is from 2025-04-07
# Scraping SBI - processing page 1
# Stopping further scraping for SBI as older data encountered.
# ✅ New data added for SBI in Nepse_Data/Commercial_Banks/SBI.csv
# 0
# 0
#
#
# 📌 SBL: Latest data in CSV is from 2025-04-07
# Scraping SBL - processing page 1
# Stopping further scraping for SBL as older data encountered.
# ✅ New data added for SBL in Nepse_Data/Commercial_Banks/SBL.csv
# 0
# 0
#
#
# 📌 SCB: Latest data in CSV is from 2025-04-07
# Scraping SCB - processing page 1
# Stopping further scraping for SCB as older data encountered.
# ✅ New data added for SCB in Nepse_Data/Commercial_Banks/SCB.csv
# 0
# 0
#
#
# 0
# 📌 EDBL: Latest data in CSV is from 2025-04-07
# Scraping EDBL - processing page 1
# Stopping further scraping for EDBL as older data encountered.
# ✅ New data added for EDBL in Nepse_Data/Development_Bank_Limited/EDBL.csv
# 0
# 0
#
#
# 📌 GBBL: Latest data in CSV is from 2025-04-07
# Scraping GBBL - processing page 1
# Stopping further scraping for GBBL as older data encountered.
# ✅ New data added for GBBL in Nepse_Data/Development_Bank_Limited/GBBL.csv
# 0
# 0
#
#
# 📌 GRDBL: Latest data in CSV is from 2025-04-07
# Scraping GRDBL - processing page 1
# Stopping further scraping for GRDBL as older data encountered.
# ✅ New data added for GRDBL in Nepse_Data/Development_Bank_Limited/GRDBL.csv
# 0
# 0
#
#
# 📌 JBBL: Latest data in CSV is from 2025-04-07
# Scraping JBBL - processing page 1
# Stopping further scraping for JBBL as older data encountered.
# ✅ New data added for JBBL in Nepse_Data/Development_Bank_Limited/JBBL.csv
# 0
# 0
#
#
# 📌 KRBL: Latest data in CSV is from 2024-12-24
# Scraping KRBL - processing page 1
# Stopping further scraping for KRBL as older data encountered.
# ⚠ No new data found for KRBL. Skipping update.
# 📌 KSBBL: Latest data in CSV is from 2025-04-07
# Scraping KSBBL - processing page 1
# Stopping further scraping for KSBBL as older data encountered.
# ✅ New data added for KSBBL in Nepse_Data/Development_Bank_Limited/KSBBL.csv
# 0
# 0
#
#
# 📌 LBBL: Latest data in CSV is from 2025-04-07
# Scraping LBBL - processing page 1
# Stopping further scraping for LBBL as older data encountered.
# ✅ New data added for LBBL in Nepse_Data/Development_Bank_Limited/LBBL.csv
# 0
# 0
#
#
# 📌 MDB: Latest data in CSV is from 2025-04-07
# Scraping MDB - processing page 1
# Stopping further scraping for MDB as older data encountered.
# ✅ New data added for MDB in Nepse_Data/Development_Bank_Limited/MDB.csv
# 0
# 0
#
#
# 📌 MLBL: Latest data in CSV is from 2025-04-07
# Scraping MLBL - processing page 1
# Stopping further scraping for MLBL as older data encountered.
# ✅ New data added for MLBL in Nepse_Data/Development_Bank_Limited/MLBL.csv
# 0
# 0
#
#
# 📌 MNBBL: Latest data in CSV is from 2025-04-07
# Scraping MNBBL - processing page 1
# Stopping further scraping for MNBBL as older data encountered.
# ✅ New data added for MNBBL in Nepse_Data/Development_Bank_Limited/MNBBL.csv
# 0
# 0
#
#
# 📌 NABBC: Latest data in CSV is from 2025-04-07
# Scraping NABBC - processing page 1
# Stopping further scraping for NABBC as older data encountered.
# ✅ New data added for NABBC in Nepse_Data/Development_Bank_Limited/NABBC.csv
# 0
# 0
#
#
# 📌 SADBL: Latest data in CSV is from 2025-04-07
# Scraping SADBL - processing page 1
# Stopping further scraping for SADBL as older data encountered.
# ✅ New data added for SADBL in Nepse_Data/Development_Bank_Limited/SADBL.csv
# 0
# 0
#
#
# 📌 SAPDBL: Latest data in CSV is from 2025-04-07
# Scraping SAPDBL - processing page 1
# Stopping further scraping for SAPDBL as older data encountered.
# ✅ New data added for SAPDBL in Nepse_Data/Development_Bank_Limited/SAPDBL.csv
# 0
# 0
#
#
# 📌 SHINE: Latest data in CSV is from 2025-04-07
# Scraping SHINE - processing page 1
# Stopping further scraping for SHINE as older data encountered.
# ✅ New data added for SHINE in Nepse_Data/Development_Bank_Limited/SHINE.csv
# 0
# 0
#
#
# 📌 SINDU: Latest data in CSV is from 2025-04-07
# Scraping SINDU - processing page 1
# Stopping further scraping for SINDU as older data encountered.
# ✅ New data added for SINDU in Nepse_Data/Development_Bank_Limited/SINDU.csv
# 0
# 0
#
#
# 0
# 📌 BFC: Latest data in CSV is from 2025-04-07
# Scraping BFC - processing page 1
# Stopping further scraping for BFC as older data encountered.
# ✅ New data added for BFC in Nepse_Data/Finance/BFC.csv
# 0
# 0
#
#
# 📌 GFCL: Latest data in CSV is from 2025-04-07
# Scraping GFCL - processing page 1
# Stopping further scraping for GFCL as older data encountered.
# ✅ New data added for GFCL in Nepse_Data/Finance/GFCL.csv
# 0
# 0
#
#
# 📌 GMFIL: Latest data in CSV is from 2025-04-07
# Scraping GMFIL - processing page 1
# Stopping further scraping for GMFIL as older data encountered.
# ✅ New data added for GMFIL in Nepse_Data/Finance/GMFIL.csv
# 0
# 0
#
#
# 📌 GUFL: Latest data in CSV is from 2025-04-07
# Scraping GUFL - processing page 1
# Stopping further scraping for GUFL as older data encountered.
# ✅ New data added for GUFL in Nepse_Data/Finance/GUFL.csv
# 0
# 0
#
#
# 📌 ICFC: Latest data in CSV is from 2025-04-07
# Scraping ICFC - processing page 1
# Stopping further scraping for ICFC as older data encountered.
# ✅ New data added for ICFC in Nepse_Data/Finance/ICFC.csv
# 0
# 0
#
#
# 📌 JFL: Latest data in CSV is from 2025-04-07
# Scraping JFL - processing page 1
# Stopping further scraping for JFL as older data encountered.
# ✅ New data added for JFL in Nepse_Data/Finance/JFL.csv
# 0
# 0
#
#
# 📌 MFIL: Latest data in CSV is from 2025-04-07
# Scraping MFIL - processing page 1
# Stopping further scraping for MFIL as older data encountered.
# ✅ New data added for MFIL in Nepse_Data/Finance/MFIL.csv
# 0
# 0
#
#
# 📌 MPFL: Latest data in CSV is from 2025-04-07
# Scraping MPFL - processing page 1
# Stopping further scraping for MPFL as older data encountered.
# ✅ New data added for MPFL in Nepse_Data/Finance/MPFL.csv
# 0
# 0
#
#
# 📌 NFS: Latest data in CSV is from 2025-04-07
# Scraping NFS - processing page 1
# Stopping further scraping for NFS as older data encountered.
# ✅ New data added for NFS in Nepse_Data/Finance/NFS.csv
# 0
# 0
#
#
# 📌 PFL: Latest data in CSV is from 2025-04-07
# Scraping PFL - processing page 1
# Stopping further scraping for PFL as older data encountered.
# ✅ New data added for PFL in Nepse_Data/Finance/PFL.csv
# 0
# 0
#
#
# 📌 PROFL: Latest data in CSV is from 2025-04-07
# Scraping PROFL - processing page 1
# Stopping further scraping for PROFL as older data encountered.
# ✅ New data added for PROFL in Nepse_Data/Finance/PROFL.csv
# 0
# 0
#
#
# 📌 RLFL: Latest data in CSV is from 2025-04-07
# Scraping RLFL - processing page 1
# Stopping further scraping for RLFL as older data encountered.
# ✅ New data added for RLFL in Nepse_Data/Finance/RLFL.csv
# 0
# 0
#
#
# 📌 SFCL: Latest data in CSV is from 2025-04-07
# Scraping SFCL - processing page 1
# Stopping further scraping for SFCL as older data encountered.
# ✅ New data added for SFCL in Nepse_Data/Finance/SFCL.csv
# 0
# 0
#
#
# 📌 SIFC: Latest data in CSV is from 2025-04-07
# Scraping SIFC - processing page 1
# Stopping further scraping for SIFC as older data encountered.
# ✅ New data added for SIFC in Nepse_Data/Finance/SIFC.csv
# 0
# 0
#
#
# 0
# 📌 CGH: Latest data in CSV is from 2025-04-07
# Scraping CGH - processing page 1
# Stopping further scraping for CGH as older data encountered.
# ✅ New data added for CGH in Nepse_Data/Hotels_And_Tourism/CGH.csv
# 0
# 0
#
#
# 📌 CITY: Latest data in CSV is from 2025-04-07
# Scraping CITY - processing page 1
# Stopping further scraping for CITY as older data encountered.
# ✅ New data added for CITY in Nepse_Data/Hotels_And_Tourism/CITY.csv
# 0
# 0
#
#
# 📌 KDL: Latest data in CSV is from 2025-04-07
# Scraping KDL - processing page 1
# Stopping further scraping for KDL as older data encountered.
# ✅ New data added for KDL in Nepse_Data/Hotels_And_Tourism/KDL.csv
# 0
# 0
#
#
# 📌 OHL: Latest data in CSV is from 2025-04-07
# Scraping OHL - processing page 1
# Stopping further scraping for OHL as older data encountered.
# ✅ New data added for OHL in Nepse_Data/Hotels_And_Tourism/OHL.csv
# 0
# 0
#
#
# 📌 SHL: Latest data in CSV is from 2025-04-07
# Scraping SHL - processing page 1
# Stopping further scraping for SHL as older data encountered.
# ✅ New data added for SHL in Nepse_Data/Hotels_And_Tourism/SHL.csv
# 0
# 0
#
#
# 📌 TRH: Latest data in CSV is from 2025-04-07
# Scraping TRH - processing page 1
# Stopping further scraping for TRH as older data encountered.
# ✅ New data added for TRH in Nepse_Data/Hotels_And_Tourism/TRH.csv
# 0
# 0
#
#
# 0
# 📌 AHL: Latest data in CSV is from 2025-04-07
# Scraping AHL - processing page 1
# Stopping further scraping for AHL as older data encountered.
# ✅ New data added for AHL in Nepse_Data/Hydro_Power/AHL.csv
# 0
# 0
#
#
# 📌 AHPC: Latest data in CSV is from 2025-04-07
# Scraping AHPC - processing page 1
# Stopping further scraping for AHPC as older data encountered.
# ✅ New data added for AHPC in Nepse_Data/Hydro_Power/AHPC.csv
# 0
# 0
#
#
# 📌 AKJCL: Latest data in CSV is from 2025-04-07
# Scraping AKJCL - processing page 1
# Stopping further scraping for AKJCL as older data encountered.
# ✅ New data added for AKJCL in Nepse_Data/Hydro_Power/AKJCL.csv
# 0
# 0
#
#
# 📌 AKPL: Latest data in CSV is from 2025-04-07
# Scraping AKPL - processing page 1
# Stopping further scraping for AKPL as older data encountered.
# ✅ New data added for AKPL in Nepse_Data/Hydro_Power/AKPL.csv
# 0
# 0
#
#
# 📌 API: Latest data in CSV is from 2025-04-07
# Scraping API - processing page 1
# Stopping further scraping for API as older data encountered.
# ✅ New data added for API in Nepse_Data/Hydro_Power/API.csv
# 0
# 0
#
#
# 📌 BARUN: Latest data in CSV is from 2025-04-07
# Scraping BARUN - processing page 1
# Stopping further scraping for BARUN as older data encountered.
# ✅ New data added for BARUN in Nepse_Data/Hydro_Power/BARUN.csv
# 0
# 0
#
#
# 📌 BEDC: Latest data in CSV is from 2025-04-07
# Scraping BEDC - processing page 1
# Stopping further scraping for BEDC as older data encountered.
# ✅ New data added for BEDC in Nepse_Data/Hydro_Power/BEDC.csv
# 0
# 0
#
#
# 📌 BGWT: Latest data in CSV is from 2025-04-07
# Scraping BGWT - processing page 1
# Stopping further scraping for BGWT as older data encountered.
# ✅ New data added for BGWT in Nepse_Data/Hydro_Power/BGWT.csv
# 0
# 0
#
#
# 📌 BHDC: Latest data in CSV is from 2025-04-07
# Scraping BHDC - processing page 1
# Stopping further scraping for BHDC as older data encountered.
# ✅ New data added for BHDC in Nepse_Data/Hydro_Power/BHDC.csv
# 0
# 0
#
#
# 📌 BHL: Latest data in CSV is from 2025-04-07
# Scraping BHL - processing page 1
# Stopping further scraping for BHL as older data encountered.
# ✅ New data added for BHL in Nepse_Data/Hydro_Power/BHL.csv
# 0
# 0
#
#
# 📌 BHPL: Latest data in CSV is from 2025-04-07
# Scraping BHPL - processing page 1
# Stopping further scraping for BHPL as older data encountered.
# ✅ New data added for BHPL in Nepse_Data/Hydro_Power/BHPL.csv
# 0
# 0
#
#
# 📌 BNHC: Latest data in CSV is from 2025-04-07
# Scraping BNHC - processing page 1
# Stopping further scraping for BNHC as older data encountered.
# ✅ New data added for BNHC in Nepse_Data/Hydro_Power/BNHC.csv
# 0
# 0
#
#
# 📌 BPCL: Latest data in CSV is from 2025-04-07
# Scraping BPCL - processing page 1
# Stopping further scraping for BPCL as older data encountered.
# ✅ New data added for BPCL in Nepse_Data/Hydro_Power/BPCL.csv
# 0
# 0
#
#
# 📌 CHCL: Latest data in CSV is from 2025-04-07
# Scraping CHCL - processing page 1
# Stopping further scraping for CHCL as older data encountered.
# ✅ New data added for CHCL in Nepse_Data/Hydro_Power/CHCL.csv
# 0
# 0
#
#
# 📌 CHL: Latest data in CSV is from 2025-04-07
# Scraping CHL - processing page 1
# Stopping further scraping for CHL as older data encountered.
# ✅ New data added for CHL in Nepse_Data/Hydro_Power/CHL.csv
# 0
# 0
#
#
# 📌 CKHL: Latest data in CSV is from 2025-04-07
# Scraping CKHL - processing page 1
# Stopping further scraping for CKHL as older data encountered.
# ✅ New data added for CKHL in Nepse_Data/Hydro_Power/CKHL.csv
# 0
# 0
#
#
# 📌 DHPL: Latest data in CSV is from 2025-04-07
# Scraping DHPL - processing page 1
# Stopping further scraping for DHPL as older data encountered.
# ✅ New data added for DHPL in Nepse_Data/Hydro_Power/DHPL.csv
# 0
# 0
#
#
# 📌 DOLTI: Latest data in CSV is from 2025-04-07
# Scraping DOLTI - processing page 1
# Stopping further scraping for DOLTI as older data encountered.
# ✅ New data added for DOLTI in Nepse_Data/Hydro_Power/DOLTI.csv
# 0
# 0
#
#
# 📌 DORDI: Latest data in CSV is from 2025-04-07
# Scraping DORDI - processing page 1
# Stopping further scraping for DORDI as older data encountered.
# ✅ New data added for DORDI in Nepse_Data/Hydro_Power/DORDI.csv
# 0
# 0
#
#
# 📌 EHPL: Latest data in CSV is from 2025-04-07
# Scraping EHPL - processing page 1
# Stopping further scraping for EHPL as older data encountered.
# ✅ New data added for EHPL in Nepse_Data/Hydro_Power/EHPL.csv
# 0
# 0
#
#
# 📌 GHL: Latest data in CSV is from 2025-04-07
# Scraping GHL - processing page 1
# Stopping further scraping for GHL as older data encountered.
# ✅ New data added for GHL in Nepse_Data/Hydro_Power/GHL.csv
# 0
# 0
#
#
# 📌 GLH: Latest data in CSV is from 2025-04-07
# Scraping GLH - processing page 1
# Stopping further scraping for GLH as older data encountered.
# ✅ New data added for GLH in Nepse_Data/Hydro_Power/GLH.csv
# 0
# 0
#
#
# 📌 GVL: Latest data in CSV is from 2025-04-07
# Scraping GVL - processing page 1
# Stopping further scraping for GVL as older data encountered.
# ✅ New data added for GVL in Nepse_Data/Hydro_Power/GVL.csv
# 0
# 0
#
#
# 📌 HDHPC: Latest data in CSV is from 2025-04-07
# Scraping HDHPC - processing page 1
# Stopping further scraping for HDHPC as older data encountered.
# ✅ New data added for HDHPC in Nepse_Data/Hydro_Power/HDHPC.csv
# 0
# 0
#
#
# 📌 HHL: Latest data in CSV is from 2025-04-07
# Scraping HHL - processing page 1
# Stopping further scraping for HHL as older data encountered.
# ✅ New data added for HHL in Nepse_Data/Hydro_Power/HHL.csv
# 0
# 0
#
#
# 📌 HPPL: Latest data in CSV is from 2025-04-07
# Scraping HPPL - processing page 1
# Stopping further scraping for HPPL as older data encountered.
# ✅ New data added for HPPL in Nepse_Data/Hydro_Power/HPPL.csv
# 0
# 0
#
#
# 📌 HURJA: Latest data in CSV is from 2025-04-07
# Scraping HURJA - processing page 1
# Stopping further scraping for HURJA as older data encountered.
# ✅ New data added for HURJA in Nepse_Data/Hydro_Power/HURJA.csv
# 0
# 0
#
#
# 📌 IHL: Latest data in CSV is from 2025-04-07
# Scraping IHL - processing page 1
# Stopping further scraping for IHL as older data encountered.
# ✅ New data added for IHL in Nepse_Data/Hydro_Power/IHL.csv
# 0
# 0
#
#
# 📌 JOSHI: Latest data in CSV is from 2025-04-07
# Scraping JOSHI - processing page 1
# Stopping further scraping for JOSHI as older data encountered.
# ✅ New data added for JOSHI in Nepse_Data/Hydro_Power/JOSHI.csv
# 0
# 0
#
#
# 📌 KBSH: Latest data in CSV is from 2025-04-07
# Scraping KBSH - processing page 1
# Stopping further scraping for KBSH as older data encountered.
# ✅ New data added for KBSH in Nepse_Data/Hydro_Power/KBSH.csv
# 0
# 0
#
#
# 📌 KKHC: Latest data in CSV is from 2025-04-07
# Scraping KKHC - processing page 1
# Stopping further scraping for KKHC as older data encountered.
# ✅ New data added for KKHC in Nepse_Data/Hydro_Power/KKHC.csv
# 0
# 0
#
#
# 📌 KPCL: Latest data in CSV is from 2025-04-07
# Scraping KPCL - processing page 1
# Stopping further scraping for KPCL as older data encountered.
# ✅ New data added for KPCL in Nepse_Data/Hydro_Power/KPCL.csv
# 0
# 0
#
#
# 📌 LEC: Latest data in CSV is from 2025-04-07
# Scraping LEC - processing page 1
# Stopping further scraping for LEC as older data encountered.
# ✅ New data added for LEC in Nepse_Data/Hydro_Power/LEC.csv
# 0
# 0
#
#
# 📌 MAKAR: Latest data in CSV is from 2025-04-07
# Scraping MAKAR - processing page 1
# Stopping further scraping for MAKAR as older data encountered.
# ✅ New data added for MAKAR in Nepse_Data/Hydro_Power/MAKAR.csv
# 0
# 0
#
#
# 📌 MANDU: Latest data in CSV is from 2025-04-07
# Scraping MANDU - processing page 1
# Stopping further scraping for MANDU as older data encountered.
# ✅ New data added for MANDU in Nepse_Data/Hydro_Power/MANDU.csv
# 0
# 0
#
#
# 📌 MBJC: Latest data in CSV is from 2025-04-07
# Scraping MBJC - processing page 1
# Stopping further scraping for MBJC as older data encountered.
# ✅ New data added for MBJC in Nepse_Data/Hydro_Power/MBJC.csv
# 0
# 0
#
#
# 📌 MCHL: Latest data in CSV is from 2025-04-07
# Scraping MCHL - processing page 1
# Stopping further scraping for MCHL as older data encountered.
# ✅ New data added for MCHL in Nepse_Data/Hydro_Power/MCHL.csv
# 0
# 0
#
#
# 📌 MEHL: Latest data in CSV is from 2025-04-07
# Scraping MEHL - processing page 1
# Stopping further scraping for MEHL as older data encountered.
# ✅ New data added for MEHL in Nepse_Data/Hydro_Power/MEHL.csv
# 0
# 0
#
#
# 📌 MEL: Latest data in CSV is from 2025-04-07
# Scraping MEL - processing page 1
# Stopping further scraping for MEL as older data encountered.
# ✅ New data added for MEL in Nepse_Data/Hydro_Power/MEL.csv
# 0
# 0
#
#
# 📌 MEN: Latest data in CSV is from 2025-04-07
# Scraping MEN - processing page 1
# Stopping further scraping for MEN as older data encountered.
# ✅ New data added for MEN in Nepse_Data/Hydro_Power/MEN.csv
# 0
# 0
#
#
# 📌 MHCL: Latest data in CSV is from 2025-04-07
# Scraping MHCL - processing page 1
# Stopping further scraping for MHCL as older data encountered.
# ✅ New data added for MHCL in Nepse_Data/Hydro_Power/MHCL.csv
# 0
# 0
#
#
# 📌 MHL: Latest data in CSV is from 2025-04-07
# Scraping MHL - processing page 1
# Stopping further scraping for MHL as older data encountered.
# ✅ New data added for MHL in Nepse_Data/Hydro_Power/MHL.csv
# 0
# 0
#
#
# 📌 MHNL: Latest data in CSV is from 2025-04-07
# Scraping MHNL - processing page 1
# Stopping further scraping for MHNL as older data encountered.
# ✅ New data added for MHNL in Nepse_Data/Hydro_Power/MHNL.csv
# 0
# 0
#
#
# 📌 MKHC: Latest data in CSV is from 2025-04-07
# Scraping MKHC - processing page 1
# Stopping further scraping for MKHC as older data encountered.
# ✅ New data added for MKHC in Nepse_Data/Hydro_Power/MKHC.csv
# 0
# 0
#
#
# 📌 MKHL: Latest data in CSV is from 2025-04-07
# Scraping MKHL - processing page 1
# Stopping further scraping for MKHL as older data encountered.
# ✅ New data added for MKHL in Nepse_Data/Hydro_Power/MKHL.csv
# 0
# 0
#
#
# 📌 MKJC: Latest data in CSV is from 2025-04-07
# Scraping MKJC - processing page 1
# Stopping further scraping for MKJC as older data encountered.
# ✅ New data added for MKJC in Nepse_Data/Hydro_Power/MKJC.csv
# 0
# 0
#
#
# 📌 MMKJL: Latest data in CSV is from 2025-04-07
# Scraping MMKJL - processing page 1
# Stopping further scraping for MMKJL as older data encountered.
# ✅ New data added for MMKJL in Nepse_Data/Hydro_Power/MMKJL.csv
# 0
# 0
#
#
# 📌 MSHL: Latest data in CSV is from 2025-04-07
# Scraping MSHL - processing page 1
# Stopping further scraping for MSHL as older data encountered.
# ✅ New data added for MSHL in Nepse_Data/Hydro_Power/MSHL.csv
# 0
# 0
#
#
# 📌 NGPL: Latest data in CSV is from 2025-04-07
# Scraping NGPL - processing page 1
# Stopping further scraping for NGPL as older data encountered.
# ✅ New data added for NGPL in Nepse_Data/Hydro_Power/NGPL.csv
# 0
# 0
#
#
# 📌 NHDL: Latest data in CSV is from 2025-04-07
# Scraping NHDL - processing page 1
# Stopping further scraping for NHDL as older data encountered.
# ✅ New data added for NHDL in Nepse_Data/Hydro_Power/NHDL.csv
# 0
# 0
#
#
# 📌 NHPC: Latest data in CSV is from 2025-04-07
# Scraping NHPC - processing page 1
# Stopping further scraping for NHPC as older data encountered.
# ✅ New data added for NHPC in Nepse_Data/Hydro_Power/NHPC.csv
# 0
# 0
#
#
# 📌 NYADI: Latest data in CSV is from 2025-04-07
# Scraping NYADI - processing page 1
# Stopping further scraping for NYADI as older data encountered.
# ✅ New data added for NYADI in Nepse_Data/Hydro_Power/NYADI.csv
# 0
# 0
#
#
# 📌 PHCL: Latest data in CSV is from 2025-04-07
# Scraping PHCL - processing page 1
# Stopping further scraping for PHCL as older data encountered.
# ✅ New data added for PHCL in Nepse_Data/Hydro_Power/PHCL.csv
# 0
# 0
#
#
# 📌 PMHPL: Latest data in CSV is from 2025-04-07
# Scraping PMHPL - processing page 1
# Stopping further scraping for PMHPL as older data encountered.
# ✅ New data added for PMHPL in Nepse_Data/Hydro_Power/PMHPL.csv
# 0
# 0
#
#
# 📌 PPCL: Latest data in CSV is from 2025-04-07
# Scraping PPCL - processing page 1
# Stopping further scraping for PPCL as older data encountered.
# ✅ New data added for PPCL in Nepse_Data/Hydro_Power/PPCL.csv
# 0
# 0
#
#
# 📌 PPL: Latest data in CSV is from 2025-04-07
# Scraping PPL - processing page 1
# Stopping further scraping for PPL as older data encountered.
# ✅ New data added for PPL in Nepse_Data/Hydro_Power/PPL.csv
# 0
# 0
#
#
# 📌 RADHI: Latest data in CSV is from 2025-04-07
# Scraping RADHI - processing page 1
# Stopping further scraping for RADHI as older data encountered.
# ✅ New data added for RADHI in Nepse_Data/Hydro_Power/RADHI.csv
# 0
# 0
#
#
# 📌 RAWA: Latest data in CSV is from 2025-04-07
# Scraping RAWA - processing page 1
# Stopping further scraping for RAWA as older data encountered.
# ✅ New data added for RAWA in Nepse_Data/Hydro_Power/RAWA.csv
# 0
# 0
#
#
# 📌 RFPL: Latest data in CSV is from 2025-04-07
# Scraping RFPL - processing page 1
# Stopping further scraping for RFPL as older data encountered.
# ✅ New data added for RFPL in Nepse_Data/Hydro_Power/RFPL.csv
# 0
# 0
#
#
# 📌 RHGCL: Latest data in CSV is from 2025-04-07
# Scraping RHGCL - processing page 1
# Stopping further scraping for RHGCL as older data encountered.
# ✅ New data added for RHGCL in Nepse_Data/Hydro_Power/RHGCL.csv
# 0
# 0
#
#
# 📌 RHPC: Latest data in CSV is from 2021-11-03
# Scraping RHPC - processing page 1
# Stopping further scraping for RHPC as older data encountered.
# ⚠ No new data found for RHPC. Skipping update.
# 📌 RHPL: Latest data in CSV is from 2025-04-07
# Scraping RHPL - processing page 1
# Stopping further scraping for RHPL as older data encountered.
# ✅ New data added for RHPL in Nepse_Data/Hydro_Power/RHPL.csv
# 0
# 0
#
#
# 📌 RIDI: Latest data in CSV is from 2025-04-07
# Scraping RIDI - processing page 1
# Stopping further scraping for RIDI as older data encountered.
# ✅ New data added for RIDI in Nepse_Data/Hydro_Power/RIDI.csv
# 0
# 0
#
#
# 📌 RURU: Latest data in CSV is from 2025-04-07
# Scraping RURU - processing page 1
# Stopping further scraping for RURU as older data encountered.
# ✅ New data added for RURU in Nepse_Data/Hydro_Power/RURU.csv
# 0
# 0
#
#
# 📌 SAHAS: Latest data in CSV is from 2025-04-07
# Scraping SAHAS - processing page 1
# Stopping further scraping for SAHAS as older data encountered.
# ✅ New data added for SAHAS in Nepse_Data/Hydro_Power/SAHAS.csv
# 0
# 0
#
#
# 📌 SGHC: Latest data in CSV is from 2025-04-07
# Scraping SGHC - processing page 1
# Stopping further scraping for SGHC as older data encountered.
# ✅ New data added for SGHC in Nepse_Data/Hydro_Power/SGHC.csv
# 0
# 0
#
#
# 📌 SHEL: Latest data in CSV is from 2025-04-07
# Scraping SHEL - processing page 1
# Stopping further scraping for SHEL as older data encountered.
# ✅ New data added for SHEL in Nepse_Data/Hydro_Power/SHEL.csv
# 0
# 0
#
#
# 📌 SHPC: Latest data in CSV is from 2025-04-07
# Scraping SHPC - processing page 1
# Stopping further scraping for SHPC as older data encountered.
# ✅ New data added for SHPC in Nepse_Data/Hydro_Power/SHPC.csv
# 0
# 0
#
#
# 📌 SIKLES: Latest data in CSV is from 2025-04-07
# Scraping SIKLES - processing page 1
# Stopping further scraping for SIKLES as older data encountered.
# ✅ New data added for SIKLES in Nepse_Data/Hydro_Power/SIKLES.csv
# 0
# 0
#
#
# 📌 SJCL: Latest data in CSV is from 2025-04-07
# Scraping SJCL - processing page 1
# Stopping further scraping for SJCL as older data encountered.
# ✅ New data added for SJCL in Nepse_Data/Hydro_Power/SJCL.csv
# 0
# 0
#
#
# 📌 SMH: Latest data in CSV is from 2025-04-07
# Scraping SMH - processing page 1
# Stopping further scraping for SMH as older data encountered.
# ✅ New data added for SMH in Nepse_Data/Hydro_Power/SMH.csv
# 0
# 0
#
#
# 📌 SMHL: Latest data in CSV is from 2025-04-07
# Scraping SMHL - processing page 1
# Stopping further scraping for SMHL as older data encountered.
# ✅ New data added for SMHL in Nepse_Data/Hydro_Power/SMHL.csv
# 0
# 0
#
#
# 📌 SMJC: Latest data in CSV is from 2025-04-07
# Scraping SMJC - processing page 1
# Stopping further scraping for SMJC as older data encountered.
# ✅ New data added for SMJC in Nepse_Data/Hydro_Power/SMJC.csv
# 0
# 0
#
#
# 📌 SPC: Latest data in CSV is from 2025-04-07
# Scraping SPC - processing page 1
# Stopping further scraping for SPC as older data encountered.
# ✅ New data added for SPC in Nepse_Data/Hydro_Power/SPC.csv
# 0
# 0
#
#
# 📌 SPDL: Latest data in CSV is from 2025-04-07
# Scraping SPDL - processing page 1
# Stopping further scraping for SPDL as older data encountered.
# ✅ New data added for SPDL in Nepse_Data/Hydro_Power/SPDL.csv
# 0
# 0
#
#
# 📌 SPHL: Latest data in CSV is from 2025-04-07
# Scraping SPHL - processing page 1
# Stopping further scraping for SPHL as older data encountered.
# ✅ New data added for SPHL in Nepse_Data/Hydro_Power/SPHL.csv
# 0
# 0
#
#
# 📌 SPL: Latest data in CSV is from 2025-04-07
# Scraping SPL - processing page 1
# Stopping further scraping for SPL as older data encountered.
# ✅ New data added for SPL in Nepse_Data/Hydro_Power/SPL.csv
# 0
# 0
#
#
# 📌 SSHL: Latest data in CSV is from 2025-04-07
# Scraping SSHL - processing page 1
# Stopping further scraping for SSHL as older data encountered.
# ✅ New data added for SSHL in Nepse_Data/Hydro_Power/SSHL.csv
# 0
# 0
#
#
# 📌 TAMOR: Latest data in CSV is from 2025-04-07
# Scraping TAMOR - processing page 1
# Stopping further scraping for TAMOR as older data encountered.
# ✅ New data added for TAMOR in Nepse_Data/Hydro_Power/TAMOR.csv
# 0
# 0
#
#
# 📌 TPC: Latest data in CSV is from 2025-04-07
# Scraping TPC - processing page 1
# Stopping further scraping for TPC as older data encountered.
# ✅ New data added for TPC in Nepse_Data/Hydro_Power/TPC.csv
# 0
# 0
#
#
# 📌 TSHL: Latest data in CSV is from 2025-04-07
# Scraping TSHL - processing page 1
# Stopping further scraping for TSHL as older data encountered.
# ✅ New data added for TSHL in Nepse_Data/Hydro_Power/TSHL.csv
# 0
# 0
#
#
# 📌 TVCL: Latest data in CSV is from 2025-04-07
# Scraping TVCL - processing page 1
# Stopping further scraping for TVCL as older data encountered.
# ✅ New data added for TVCL in Nepse_Data/Hydro_Power/TVCL.csv
# 0
# 0
#
#
# 📌 UHEWA: Latest data in CSV is from 2025-04-07
# Scraping UHEWA - processing page 1
# Stopping further scraping for UHEWA as older data encountered.
# ✅ New data added for UHEWA in Nepse_Data/Hydro_Power/UHEWA.csv
# 0
# 0
#
#
# 📌 ULHC: Latest data in CSV is from 2025-04-07
# Scraping ULHC - processing page 1
# Stopping further scraping for ULHC as older data encountered.
# ✅ New data added for ULHC in Nepse_Data/Hydro_Power/ULHC.csv
# 0
# 0
#
#
# 📌 UMHL: Latest data in CSV is from 2025-04-07
# Scraping UMHL - processing page 1
# Stopping further scraping for UMHL as older data encountered.
# ✅ New data added for UMHL in Nepse_Data/Hydro_Power/UMHL.csv
# 0
# 0
#
#
# 📌 UMRH: Latest data in CSV is from 2025-04-07
# Scraping UMRH - processing page 1
# Stopping further scraping for UMRH as older data encountered.
# ✅ New data added for UMRH in Nepse_Data/Hydro_Power/UMRH.csv
# 0
# 0
#
#
# 📌 UNHPL: Latest data in CSV is from 2025-04-07
# Scraping UNHPL - processing page 1
# Stopping further scraping for UNHPL as older data encountered.
# ✅ New data added for UNHPL in Nepse_Data/Hydro_Power/UNHPL.csv
# 0
# 0
#
#
# 📌 UPCL: Latest data in CSV is from 2025-04-07
# Scraping UPCL - processing page 1
# Stopping further scraping for UPCL as older data encountered.
# ✅ New data added for UPCL in Nepse_Data/Hydro_Power/UPCL.csv
# 0
# 0
#
#
# 📌 UPPER: Latest data in CSV is from 2025-04-07
# Scraping UPPER - processing page 1
# Stopping further scraping for UPPER as older data encountered.
# ✅ New data added for UPPER in Nepse_Data/Hydro_Power/UPPER.csv
# 0
# 0
#
#
# 📌 USHEC: Latest data in CSV is from 2025-04-07
# Scraping USHEC - processing page 1
# Stopping further scraping for USHEC as older data encountered.
# ✅ New data added for USHEC in Nepse_Data/Hydro_Power/USHEC.csv
# 0
# 0
#
#
# 📌 USHL: Latest data in CSV is from 2025-04-07
# Scraping USHL - processing page 1
# Stopping further scraping for USHL as older data encountered.
# ✅ New data added for USHL in Nepse_Data/Hydro_Power/USHL.csv
# 0
# 0
#
#
# 📌 VLUCL: Latest data in CSV is from 2025-04-07
# Scraping VLUCL - processing page 1
# Stopping further scraping for VLUCL as older data encountered.
# ✅ New data added for VLUCL in Nepse_Data/Hydro_Power/VLUCL.csv
# 0
# 0
#
#
# 0
# 📌 CHDC: Latest data in CSV is from 2025-04-07
# Scraping CHDC - processing page 1
# Stopping further scraping for CHDC as older data encountered.
# ✅ New data added for CHDC in Nepse_Data/Investment/CHDC.csv
# 0
# 0
#
#
# 📌 CIT: Latest data in CSV is from 2025-04-07
# Scraping CIT - processing page 1
# Stopping further scraping for CIT as older data encountered.
# ✅ New data added for CIT in Nepse_Data/Investment/CIT.csv
# 0
# 0
#
#
# 📌 ENL: Latest data in CSV is from 2025-04-07
# Scraping ENL - processing page 1
# Stopping further scraping for ENL as older data encountered.
# ✅ New data added for ENL in Nepse_Data/Investment/ENL.csv
# 0
# 0
#
#
# 📌 HATHY: Latest data in CSV is from 2025-04-07
# Scraping HATHY - processing page 1
# Stopping further scraping for HATHY as older data encountered.
# ✅ New data added for HATHY in Nepse_Data/Investment/HATHY.csv
# 0
# 0
#
#
# 📌 HIDCL: Latest data in CSV is from 2025-04-07
# Scraping HIDCL - processing page 1
# Stopping further scraping for HIDCL as older data encountered.
# ✅ New data added for HIDCL in Nepse_Data/Investment/HIDCL.csv
# 0
# 0
#
#
# 📌 NIFRA: Latest data in CSV is from 2025-04-07
# Scraping NIFRA - processing page 1
# Stopping further scraping for NIFRA as older data encountered.
# ✅ New data added for NIFRA in Nepse_Data/Investment/NIFRA.csv
# 0
# 0
#
#
# 📌 NRN: Latest data in CSV is from 2025-04-07
# Scraping NRN - processing page 1
# Stopping further scraping for NRN as older data encountered.
# ✅ New data added for NRN in Nepse_Data/Investment/NRN.csv
# 0
# 0
#
#
# 0
# 📌 ALICL: Latest data in CSV is from 2025-04-07
# Scraping ALICL - processing page 1
# Stopping further scraping for ALICL as older data encountered.
# ✅ New data added for ALICL in Nepse_Data/Life_Insurance/ALICL.csv
# 0
# 0
#
#
# 📌 CLI: Latest data in CSV is from 2025-04-07
# Scraping CLI - processing page 1
# Stopping further scraping for CLI as older data encountered.
# ✅ New data added for CLI in Nepse_Data/Life_Insurance/CLI.csv
# 0
# 0
#
#
# 📌 GMLI: Latest data in CSV is from 2025-04-07
# Scraping GMLI - processing page 1
# Stopping further scraping for GMLI as older data encountered.
# ✅ New data added for GMLI in Nepse_Data/Life_Insurance/GMLI.csv
# 0
# 0
#
#
# 📌 HLI: Latest data in CSV is from 2025-04-07
# Scraping HLI - processing page 1
# Stopping further scraping for HLI as older data encountered.
# ✅ New data added for HLI in Nepse_Data/Life_Insurance/HLI.csv
# 0
# 0
#
#
# 📌 ILI: Latest data in CSV is from 2025-04-07
# Scraping ILI - processing page 1
# Stopping further scraping for ILI as older data encountered.
# ✅ New data added for ILI in Nepse_Data/Life_Insurance/ILI.csv
# 0
# 0
#
#
# 📌 LICN: Latest data in CSV is from 2025-04-07
# Scraping LICN - processing page 1
# Stopping further scraping for LICN as older data encountered.
# ✅ New data added for LICN in Nepse_Data/Life_Insurance/LICN.csv
# 0
# 0
#
#
# 📌 NLIC: Latest data in CSV is from 2025-04-07
# Scraping NLIC - processing page 1
# Stopping further scraping for NLIC as older data encountered.
# ✅ New data added for NLIC in Nepse_Data/Life_Insurance/NLIC.csv
# 0
# 0
#
#
# 📌 NLICL: Latest data in CSV is from 2025-04-07
# Scraping NLICL - processing page 1
# Stopping further scraping for NLICL as older data encountered.
# ✅ New data added for NLICL in Nepse_Data/Life_Insurance/NLICL.csv
# 0
# 0
#
#
# 📌 PMLI: Latest data in CSV is from 2025-04-07
# Scraping PMLI - processing page 1
# Stopping further scraping for PMLI as older data encountered.
# ✅ New data added for PMLI in Nepse_Data/Life_Insurance/PMLI.csv
# 0
# 0
#
#
# 📌 RNLI: Latest data in CSV is from 2025-04-07
# Scraping RNLI - processing page 1
# Stopping further scraping for RNLI as older data encountered.
# ✅ New data added for RNLI in Nepse_Data/Life_Insurance/RNLI.csv
# 0
# 0
#
#
# 📌 SJLIC: Latest data in CSV is from 2025-04-07
# Scraping SJLIC - processing page 1
# Stopping further scraping for SJLIC as older data encountered.
# ✅ New data added for SJLIC in Nepse_Data/Life_Insurance/SJLIC.csv
# 0
# 0
#
#
# 📌 SNLI: Latest data in CSV is from 2025-04-07
# Scraping SNLI - processing page 1
# Stopping further scraping for SNLI as older data encountered.
# ✅ New data added for SNLI in Nepse_Data/Life_Insurance/SNLI.csv
# 0
# 0
#
#
# 📌 SRLI: Latest data in CSV is from 2025-04-07
# Scraping SRLI - processing page 1
# Stopping further scraping for SRLI as older data encountered.
# ✅ New data added for SRLI in Nepse_Data/Life_Insurance/SRLI.csv
# 0
# 0
#
#
# 0
# 📌 BNL: Latest data in CSV is from 2025-04-07
# Scraping BNL - processing page 1
# Stopping further scraping for BNL as older data encountered.
# ✅ New data added for BNL in Nepse_Data/Manufacturing_And_Processing/BNL.csv
# 0
# 0
#
#
# 📌 BNT: Latest data in CSV is from 2025-04-07
# Scraping BNT - processing page 1
# Stopping further scraping for BNT as older data encountered.
# ✅ New data added for BNT in Nepse_Data/Manufacturing_And_Processing/BNT.csv
# 0
# 0
#
#
# 📌 GCIL: Latest data in CSV is from 2025-04-07
# Scraping GCIL - processing page 1
# Stopping further scraping for GCIL as older data encountered.
# ✅ New data added for GCIL in Nepse_Data/Manufacturing_And_Processing/GCIL.csv
# 0
# 0
#
#
# 📌 HDL: Latest data in CSV is from 2025-04-07
# Scraping HDL - processing page 1
# Stopping further scraping for HDL as older data encountered.
# ✅ New data added for HDL in Nepse_Data/Manufacturing_And_Processing/HDL.csv
# 0
# 0
#
#
# 📌 NLO: Latest data in CSV is from 2025-03-20
# Scraping NLO - processing page 1
# Stopping further scraping for NLO as older data encountered.
# ⚠ No new data found for NLO. Skipping update.
# 📌 SARBTM: Latest data in CSV is from 2025-04-07
# Scraping SARBTM - processing page 1
# Stopping further scraping for SARBTM as older data encountered.
# ✅ New data added for SARBTM in Nepse_Data/Manufacturing_And_Processing/SARBTM.csv
# 0
# 0
#
#
# 📌 SHIVM: Latest data in CSV is from 2025-04-07
# Scraping SHIVM - processing page 1
# Stopping further scraping for SHIVM as older data encountered.
# ✅ New data added for SHIVM in Nepse_Data/Manufacturing_And_Processing/SHIVM.csv
# 0
# 0
#
#
# 📌 SONA: Latest data in CSV is from 2025-04-07
# Scraping SONA - processing page 1
# Stopping further scraping for SONA as older data encountered.
# ✅ New data added for SONA in Nepse_Data/Manufacturing_And_Processing/SONA.csv
# 0
# 0
#
#
# 📌 UNL: Latest data in CSV is from 2025-04-07
# Scraping UNL - processing page 1
# Stopping further scraping for UNL as older data encountered.
# ✅ New data added for UNL in Nepse_Data/Manufacturing_And_Processing/UNL.csv
# 0
# 0
#
#
# 0
# 📌 ACLBSL: Latest data in CSV is from 2025-04-07
# Scraping ACLBSL - processing page 1
# Stopping further scraping for ACLBSL as older data encountered.
# ✅ New data added for ACLBSL in Nepse_Data/Microfinance/ACLBSL.csv
# 0
# 0
#
#
# 📌 ADLB: Latest data in CSV is from 2023-06-15
# Scraping ADLB - processing page 1
# Stopping further scraping for ADLB as older data encountered.
# ⚠ No new data found for ADLB. Skipping update.
# 📌 ALBSL: Latest data in CSV is from 2025-04-07
# Scraping ALBSL - processing page 1
# Stopping further scraping for ALBSL as older data encountered.
# ✅ New data added for ALBSL in Nepse_Data/Microfinance/ALBSL.csv
# 0
# 0
#
#
# 📌 ANLB: Latest data in CSV is from 2025-04-07
# Scraping ANLB - processing page 1
# Stopping further scraping for ANLB as older data encountered.
# ✅ New data added for ANLB in Nepse_Data/Microfinance/ANLB.csv
# 0
# 0
#
#
# 📌 AVYAN: Latest data in CSV is from 2025-04-07
# Scraping AVYAN - processing page 1
# Stopping further scraping for AVYAN as older data encountered.
# ✅ New data added for AVYAN in Nepse_Data/Microfinance/AVYAN.csv
# 0
# 0
#
#
# 📌 CBBL: Latest data in CSV is from 2025-04-07
# Scraping CBBL - processing page 1
# Stopping further scraping for CBBL as older data encountered.
# ✅ New data added for CBBL in Nepse_Data/Microfinance/CBBL.csv
# 0
# 0
#
#
# 📌 CYCL: Latest data in CSV is from 2025-04-07
# Scraping CYCL - processing page 1
# Stopping further scraping for CYCL as older data encountered.
# ✅ New data added for CYCL in Nepse_Data/Microfinance/CYCL.csv
# 0
# 0
#
#
# 📌 DDBL: Latest data in CSV is from 2025-04-07
# Scraping DDBL - processing page 1
# Stopping further scraping for DDBL as older data encountered.
# ✅ New data added for DDBL in Nepse_Data/Microfinance/DDBL.csv
# 0
# 0
#
#
# 📌 DLBS: Latest data in CSV is from 2025-04-07
# Scraping DLBS - processing page 1
# Stopping further scraping for DLBS as older data encountered.
# ✅ New data added for DLBS in Nepse_Data/Microfinance/DLBS.csv
# 0
# 0
#
#
# 📌 FMDBL: Latest data in CSV is from 2025-04-07
# Scraping FMDBL - processing page 1
# Stopping further scraping for FMDBL as older data encountered.
# ✅ New data added for FMDBL in Nepse_Data/Microfinance/FMDBL.csv
# 0
# 0
#
#
# 📌 FOWAD: Latest data in CSV is from 2025-04-07
# Scraping FOWAD - processing page 1
# Stopping further scraping for FOWAD as older data encountered.
# ✅ New data added for FOWAD in Nepse_Data/Microfinance/FOWAD.csv
# 0
# 0
#
#
# 📌 GBLBS: Latest data in CSV is from 2025-04-07
# Scraping GBLBS - processing page 1
# Stopping further scraping for GBLBS as older data encountered.
# ✅ New data added for GBLBS in Nepse_Data/Microfinance/GBLBS.csv
# 0
# 0
#
#
# 📌 GILB: Latest data in CSV is from 2025-04-07
# Scraping GILB - processing page 1
# Stopping further scraping for GILB as older data encountered.
# ✅ New data added for GILB in Nepse_Data/Microfinance/GILB.csv
# 0
# 0
#
#
# 📌 GLBSL: Latest data in CSV is from 2025-04-07
# Scraping GLBSL - processing page 1
# Stopping further scraping for GLBSL as older data encountered.
# ✅ New data added for GLBSL in Nepse_Data/Microfinance/GLBSL.csv
# 0
# 0
#
#
# 📌 GMFBS: Latest data in CSV is from 2025-04-07
# Scraping GMFBS - processing page 1
# Stopping further scraping for GMFBS as older data encountered.
# ✅ New data added for GMFBS in Nepse_Data/Microfinance/GMFBS.csv
# 0
# 0
#
#
# 📌 HLBSL: Latest data in CSV is from 2025-04-07
# Scraping HLBSL - processing page 1
# Stopping further scraping for HLBSL as older data encountered.
# ✅ New data added for HLBSL in Nepse_Data/Microfinance/HLBSL.csv
# 0
# 0
#
#
# 📌 ILBS: Latest data in CSV is from 2025-04-07
# Scraping ILBS - processing page 1
# Stopping further scraping for ILBS as older data encountered.
# ✅ New data added for ILBS in Nepse_Data/Microfinance/ILBS.csv
# 0
# 0
#
#
# 📌 JBLB: Latest data in CSV is from 2025-04-07
# Scraping JBLB - processing page 1
# Stopping further scraping for JBLB as older data encountered.
# ✅ New data added for JBLB in Nepse_Data/Microfinance/JBLB.csv
# 0
# 0
#
#
# 📌 JSLBB: Latest data in CSV is from 2025-04-07
# Scraping JSLBB - processing page 1
# Stopping further scraping for JSLBB as older data encountered.
# ✅ New data added for JSLBB in Nepse_Data/Microfinance/JSLBB.csv
# 0
# 0
#
#
# 📌 KLBSL: Latest data in CSV is from 2024-07-10
# Scraping KLBSL - processing page 1
# Stopping further scraping for KLBSL as older data encountered.
# ⚠ No new data found for KLBSL. Skipping update.
# 📌 KMCDB: Latest data in CSV is from 2025-04-07
# Scraping KMCDB - processing page 1
# Stopping further scraping for KMCDB as older data encountered.
# ✅ New data added for KMCDB in Nepse_Data/Microfinance/KMCDB.csv
# 0
# 0
#
#
# 📌 LLBS: Latest data in CSV is from 2025-04-07
# Scraping LLBS - processing page 1
# Stopping further scraping for LLBS as older data encountered.
# ✅ New data added for LLBS in Nepse_Data/Microfinance/LLBS.csv
# 0
# 0
#
#
# 📌 MATRI: Latest data in CSV is from 2025-04-07
# Scraping MATRI - processing page 1
# Stopping further scraping for MATRI as older data encountered.
# ✅ New data added for MATRI in Nepse_Data/Microfinance/MATRI.csv
# 0
# 0
#
#
# 📌 MERO: Latest data in CSV is from 2025-04-07
# Scraping MERO - processing page 1
# Stopping further scraping for MERO as older data encountered.
# ✅ New data added for MERO in Nepse_Data/Microfinance/MERO.csv
# 0
# 0
#
#
# 📌 MLBBL: Latest data in CSV is from 2025-04-07
# Scraping MLBBL - processing page 1
# Stopping further scraping for MLBBL as older data encountered.
# ✅ New data added for MLBBL in Nepse_Data/Microfinance/MLBBL.csv
# 0
# 0
#
#
# 📌 MLBS: Latest data in CSV is from 2025-04-07
# Scraping MLBS - processing page 1
# Stopping further scraping for MLBS as older data encountered.
# ✅ New data added for MLBS in Nepse_Data/Microfinance/MLBS.csv
# 0
# 0
#
#
# 📌 MLBSL: Latest data in CSV is from 2025-04-07
# Scraping MLBSL - processing page 1
# Stopping further scraping for MLBSL as older data encountered.
# ✅ New data added for MLBSL in Nepse_Data/Microfinance/MLBSL.csv
# 0
# 0
#
#
# 📌 MMFDB: Latest data in CSV is from 2024-03-12
# Scraping MMFDB - processing page 1
# Stopping further scraping for MMFDB as older data encountered.
# ⚠ No new data found for MMFDB. Skipping update.
# 📌 MSLB: Latest data in CSV is from 2025-04-07
# Scraping MSLB - processing page 1
# Stopping further scraping for MSLB as older data encountered.
# ✅ New data added for MSLB in Nepse_Data/Microfinance/MSLB.csv
# 0
# 0
#
#
# 📌 NADEP: Latest data in CSV is from 2025-04-07
# Scraping NADEP - processing page 1
# Stopping further scraping for NADEP as older data encountered.
# ✅ New data added for NADEP in Nepse_Data/Microfinance/NADEP.csv
# 0
# 0
#
#
# 📌 NESDO: Latest data in CSV is from 2025-04-07
# Scraping NESDO - processing page 1
# Stopping further scraping for NESDO as older data encountered.
# ✅ New data added for NESDO in Nepse_Data/Microfinance/NESDO.csv
# 0
# 0
#
#
# 📌 NICLBSL: Latest data in CSV is from 2025-04-07
# Scraping NICLBSL - processing page 1
# Stopping further scraping for NICLBSL as older data encountered.
# ✅ New data added for NICLBSL in Nepse_Data/Microfinance/NICLBSL.csv
# 0
# 0
#
#
# 📌 NLBBL: Latest data in CSV is from 2024-03-12
# Scraping NLBBL - processing page 1
# Stopping further scraping for NLBBL as older data encountered.
# ⚠ No new data found for NLBBL. Skipping update.
# 📌 NMBMF: Latest data in CSV is from 2025-04-07
# Scraping NMBMF - processing page 1
# Stopping further scraping for NMBMF as older data encountered.
# ✅ New data added for NMBMF in Nepse_Data/Microfinance/NMBMF.csv
# 0
# 0
#
#
# 📌 NMFBS: Latest data in CSV is from 2025-04-07
# Scraping NMFBS - processing page 1
# Stopping further scraping for NMFBS as older data encountered.
# ✅ New data added for NMFBS in Nepse_Data/Microfinance/NMFBS.csv
# 0
# 0
#
#
# 📌 NMLBBL: Latest data in CSV is from 2025-04-07
# Scraping NMLBBL - processing page 1
# Stopping further scraping for NMLBBL as older data encountered.
# ✅ New data added for NMLBBL in Nepse_Data/Microfinance/NMLBBL.csv
# 0
# 0
#
#
# 📌 NSLB: Latest data in CSV is from 2023-07-13
# Scraping NSLB - processing page 1
# Stopping further scraping for NSLB as older data encountered.
# ⚠ No new data found for NSLB. Skipping update.
# 📌 NUBL: Latest data in CSV is from 2025-04-07
# Scraping NUBL - processing page 1
# Stopping further scraping for NUBL as older data encountered.
# ✅ New data added for NUBL in Nepse_Data/Microfinance/NUBL.csv
# 0
# 0
#
#
# 📌 RSDC: Latest data in CSV is from 2025-04-07
# Scraping RSDC - processing page 1
# Stopping further scraping for RSDC as older data encountered.
# ✅ New data added for RSDC in Nepse_Data/Microfinance/RSDC.csv
# 0
# 0
#
#
# 📌 RULB: Latest data in CSV is from 2023-07-13
# Scraping RULB - processing page 1
# Stopping further scraping for RULB as older data encountered.
# ⚠ No new data found for RULB. Skipping update.
# 📌 SAMAJ: Latest data in CSV is from 2025-04-07
# Scraping SAMAJ - processing page 1
# Stopping further scraping for SAMAJ as older data encountered.
# ✅ New data added for SAMAJ in Nepse_Data/Microfinance/SAMAJ.csv
# 0
# 0
#
#
# 📌 SHLB: Latest data in CSV is from 2025-04-07
# Scraping SHLB - processing page 1
# Stopping further scraping for SHLB as older data encountered.
# ✅ New data added for SHLB in Nepse_Data/Microfinance/SHLB.csv
# 0
# 0
#
#
# 📌 SKBBL: Latest data in CSV is from 2025-04-07
# Scraping SKBBL - processing page 1
# Stopping further scraping for SKBBL as older data encountered.
# ✅ New data added for SKBBL in Nepse_Data/Microfinance/SKBBL.csv
# 0
# 0
#
#
# 📌 SLBBL: Latest data in CSV is from 2025-04-07
# Scraping SLBBL - processing page 1
# Stopping further scraping for SLBBL as older data encountered.
# ✅ New data added for SLBBL in Nepse_Data/Microfinance/SLBBL.csv
# 0
# 0
#
#
# 📌 SLBSL: Latest data in CSV is from 2025-04-07
# Scraping SLBSL - processing page 1
# Stopping further scraping for SLBSL as older data encountered.
# ✅ New data added for SLBSL in Nepse_Data/Microfinance/SLBSL.csv
# 0
# 0
#
#
# 📌 SMATA: Latest data in CSV is from 2025-04-07
# Scraping SMATA - processing page 1
# Stopping further scraping for SMATA as older data encountered.
# ✅ New data added for SMATA in Nepse_Data/Microfinance/SMATA.csv
# 0
# 0
#
#
# 📌 SMB: Latest data in CSV is from 2025-04-07
# Scraping SMB - processing page 1
# Stopping further scraping for SMB as older data encountered.
# ✅ New data added for SMB in Nepse_Data/Microfinance/SMB.csv
# 0
# 0
#
#
# 📌 SMFBS: Latest data in CSV is from 2025-04-07
# Scraping SMFBS - processing page 1
# Stopping further scraping for SMFBS as older data encountered.
# ✅ New data added for SMFBS in Nepse_Data/Microfinance/SMFBS.csv
# 0
# 0
#
#
# 📌 SMFDB: Latest data in CSV is from 2023-07-13
# Scraping SMFDB - processing page 1
# Stopping further scraping for SMFDB as older data encountered.
# ⚠ No new data found for SMFDB. Skipping update.
# 📌 SMPDA: Latest data in CSV is from 2025-04-07
# Scraping SMPDA - processing page 1
# Stopping further scraping for SMPDA as older data encountered.
# ✅ New data added for SMPDA in Nepse_Data/Microfinance/SMPDA.csv
# 0
# 0
#
#
# 📌 SWBBL: Latest data in CSV is from 2025-04-07
# Scraping SWBBL - processing page 1
# ...
# ⚠ No new data found for NFSPO. Skipping update.
# 📌 NICAP: Latest data in CSV is from 2024-06-18
# Scraping NICAP - processing page 1
# Stopping further scraping for NICAP as older data encountered.
# ⚠ No new data found for NICAP. Skipping update.
# 📌 NICLBSLP: Latest data in CSV is from 2022-10-12
# Scraping NICLBSLP - processing page 1
# Stopping further scraping for NICLBSLP as older data encountered.
# ⚠ No new data found for NICLBSLP. Skipping update.
# 📌 NICLPO: Latest data in CSV is from 2025-02-10
# Scraping NICLPO - processing page 1
# Stopping further scraping for NICLPO as older data encountered.
# ⚠ No new data found for NICLPO. Skipping update.
# 📌 NIFRAP: Latest data in CSV is from 2024-12-24
# Scraping NIFRAP - processing page 1
# Stopping further scraping for NIFRAP as older data encountered.
# ⚠ No new data found for NIFRAP. Skipping update.
# 📌 NILPO: Latest data in CSV is from 2024-06-23
# Scraping NILPO - processing page 1
# Stopping further scraping for NILPO as older data encountered.
# ⚠ No new data found for NILPO. Skipping update.
# 📌 NIMBPO: Latest data in CSV is from 2025-04-07
# Scraping NIMBPO - processing page 1
# Stopping further scraping for NIMBPO as older data encountered.
# ✅ New data added for NIMBPO in Nepse_Data/Promotor_Share/NIMBPO.csv
# 0
# 0
#
#
# 📌 NLBBLP: Latest data in CSV is from 2024-02-08
# Scraping NLBBLP - processing page 1
# Stopping further scraping for NLBBLP as older data encountered.
# ⚠ No new data found for NLBBLP. Skipping update.
# Error accessing price history for NLGPO: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 NLICLP: Latest data in CSV is from 2025-02-10
# Scraping NLICLP - processing page 1
# Stopping further scraping for NLICLP as older data encountered.
# ⚠ No new data found for NLICLP. Skipping update.
# 📌 NMBMFP: Latest data in CSV is from 2019-10-23
# Scraping NMBMFP - processing page 1
# Stopping further scraping for NMBMFP as older data encountered.
# ⚠ No new data found for NMBMFP. Skipping update.
# 📌 NMBPO: Latest data in CSV is from 2025-01-16
# Scraping NMBPO - processing page 1
# Stopping further scraping for NMBPO as older data encountered.
# ⚠ No new data found for NMBPO. Skipping update.
# 📌 NMFBSP: Latest data in CSV is from 2024-11-26
# Scraping NMFBSP - processing page 1
# Stopping further scraping for NMFBSP as older data encountered.
# ⚠ No new data found for NMFBSP. Skipping update.
# 📌 NMLBBLP: Latest data in CSV is from 2025-02-10
# Scraping NMLBBLP - processing page 1
# Stopping further scraping for NMLBBLP as older data encountered.
# ⚠ No new data found for NMLBBLP. Skipping update.
# 📌 NUBLPO: Latest data in CSV is from 2021-07-01
# Scraping NUBLPO - processing page 1
# Stopping further scraping for NUBLPO as older data encountered.
# ⚠ No new data found for NUBLPO. Skipping update.
# 📌 PCBLP: Latest data in CSV is from 2025-03-25
# Scraping PCBLP - processing page 1
# Stopping further scraping for PCBLP as older data encountered.
# ⚠ No new data found for PCBLP. Skipping update.
# 📌 PFLPO: Latest data in CSV is from 2022-07-29
# Scraping PFLPO - processing page 1
# Stopping further scraping for PFLPO as older data encountered.
# ⚠ No new data found for PFLPO. Skipping update.
# 📌 PMLIP: Latest data in CSV is from 2025-02-11
# Scraping PMLIP - processing page 1
# Stopping further scraping for PMLIP as older data encountered.
# ⚠ No new data found for PMLIP. Skipping update.
# 📌 PRINPO: Latest data in CSV is from 2022-03-30
# Scraping PRINPO - processing page 1
# Stopping further scraping for PRINPO as older data encountered.
# ⚠ No new data found for PRINPO. Skipping update.
# 📌 PROFLP: Latest data in CSV is from 2025-04-01
# Scraping PROFLP - processing page 1
# Stopping further scraping for PROFLP as older data encountered.
# ⚠ No new data found for PROFLP. Skipping update.
# 📌 PRVUPO: Latest data in CSV is from 2025-04-07
# Scraping PRVUPO - processing page 1
# Stopping further scraping for PRVUPO as older data encountered.
# ⚠ No new data found for PRVUPO. Skipping update.
# 📌 RBCLPO: Latest data in CSV is from 2025-04-07
# Scraping RBCLPO - processing page 1
# Stopping further scraping for RBCLPO as older data encountered.
# ✅ New data added for RBCLPO in Nepse_Data/Promotor_Share/RBCLPO.csv
# 0
# 0
#
#
# 📌 RLFLPO: Latest data in CSV is from 2025-02-16
# Scraping RLFLPO - processing page 1
# Stopping further scraping for RLFLPO as older data encountered.
# ⚠ No new data found for RLFLPO. Skipping update.
# Error accessing price history for RNLIP: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 RSDCP: Latest data in CSV is from 2023-12-03
# Scraping RSDCP - processing page 1
# Stopping further scraping for RSDCP as older data encountered.
# ⚠ No new data found for RSDCP. Skipping update.
# 📌 SADBLP: Latest data in CSV is from 2025-03-26
# Scraping SADBLP - processing page 1
# Stopping further scraping for SADBLP as older data encountered.
# ⚠ No new data found for SADBLP. Skipping update.
# 📌 SALICOPO: Latest data in CSV is from 2024-08-22
# Scraping SALICOPO - processing page 1
# Stopping further scraping for SALICOPO as older data encountered.
# ⚠ No new data found for SALICOPO. Skipping update.
# 📌 SAPDBLP: Latest data in CSV is from 2025-03-16
# Scraping SAPDBLP - processing page 1
# Stopping further scraping for SAPDBLP as older data encountered.
# ⚠ No new data found for SAPDBLP. Skipping update.
# Error accessing price history for SBIPO: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 SBLPO: Latest data in CSV is from 2024-07-21
# Scraping SBLPO - processing page 1
# Stopping further scraping for SBLPO as older data encountered.
# ⚠ No new data found for SBLPO. Skipping update.
# Error accessing price history for SCBPO: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 SFCLP: Latest data in CSV is from 2023-06-21
# Scraping SFCLP - processing page 1
# Stopping further scraping for SFCLP as older data encountered.
# ⚠ No new data found for SFCLP. Skipping update.
# 📌 SGICP: Latest data in CSV is from 2025-03-23
# Scraping SGICP - processing page 1
# Stopping further scraping for SGICP as older data encountered.
# ⚠ No new data found for SGICP. Skipping update.
# 📌 SHINEP: Latest data in CSV is from 2025-04-07
# Scraping SHINEP - processing page 1
# Stopping further scraping for SHINEP as older data encountered.
# ⚠ No new data found for SHINEP. Skipping update.
# 📌 SICLPO: Latest data in CSV is from 2025-02-06
# Scraping SICLPO - processing page 1
# Stopping further scraping for SICLPO as older data encountered.
# ⚠ No new data found for SICLPO. Skipping update.
# 📌 SIFCPO: Latest data in CSV is from 2024-05-09
# Scraping SIFCPO - processing page 1
# Stopping further scraping for SIFCPO as older data encountered.
# ⚠ No new data found for SIFCPO. Skipping update.
# 📌 SINDUP: Latest data in CSV is from 2024-03-13
# Scraping SINDUP - processing page 1
# Stopping further scraping for SINDUP as older data encountered.
# ⚠ No new data found for SINDUP. Skipping update.
# 📌 SKBBLP: Latest data in CSV is from 2025-04-07
# Scraping SKBBLP - processing page 1
# Stopping further scraping for SKBBLP as older data encountered.
# ⚠ No new data found for SKBBLP. Skipping update.
# 📌 SLBBLP: Latest data in CSV is from 2025-01-26
# Scraping SLBBLP - processing page 1
# Stopping further scraping for SLBBLP as older data encountered.
# ⚠ No new data found for SLBBLP. Skipping update.
# Error accessing price history for SLBSLPO: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 SLICLP: Latest data in CSV is from 2022-03-21
# Scraping SLICLP - processing page 1
# Stopping further scraping for SLICLP as older data encountered.
# ⚠ No new data found for SLICLP. Skipping update.
# 📌 SMATAP: Latest data in CSV is from 2024-11-20
# Scraping SMATAP - processing page 1
# Stopping further scraping for SMATAP as older data encountered.
# ⚠ No new data found for SMATAP. Skipping update.
# 📌 SMBPO: Latest data in CSV is from 2025-03-25
# Scraping SMBPO - processing page 1
# Stopping further scraping for SMBPO as older data encountered.
# ⚠ No new data found for SMBPO. Skipping update.
# 📌 SMFBSP: Latest data in CSV is from 2023-05-09
# Scraping SMFBSP - processing page 1
# Stopping further scraping for SMFBSP as older data encountered.
# ⚠ No new data found for SMFBSP. Skipping update.
# 📌 SMFDBP: Latest data in CSV is from 2023-04-26
# Scraping SMFDBP - processing page 1
# Stopping further scraping for SMFDBP as older data encountered.
# ⚠ No new data found for SMFDBP. Skipping update.
# 📌 SMPDAP: Latest data in CSV is from 2025-02-17
# Scraping SMPDAP - processing page 1
# Stopping further scraping for SMPDAP as older data encountered.
# ⚠ No new data found for SMPDAP. Skipping update.
# Error accessing price history for SNLIP: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 SNMAPO: Latest data in CSV is from 2025-02-24
# Scraping SNMAPO - processing page 1
# Stopping further scraping for SNMAPO as older data encountered.
# ⚠ No new data found for SNMAPO. Skipping update.
# 📌 SPILPO: Latest data in CSV is from 2024-07-14
# Scraping SPILPO - processing page 1
# Stopping further scraping for SPILPO as older data encountered.
# ⚠ No new data found for SPILPO. Skipping update.
# 📌 SRBLPO: Latest data in CSV is from 2022-07-21
# Scraping SRBLPO - processing page 1
# Stopping further scraping for SRBLPO as older data encountered.
# ⚠ No new data found for SRBLPO. Skipping update.
# Error accessing price history for SRLIP: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 SWBBLP: Latest data in CSV is from 2024-08-06
# Scraping SWBBLP - processing page 1
# Stopping further scraping for SWBBLP as older data encountered.
# ⚠ No new data found for SWBBLP. Skipping update.
# 📌 SWMFPO: Latest data in CSV is from 2025-01-21
# Scraping SWMFPO - processing page 1
# Stopping further scraping for SWMFPO as older data encountered.
# ⚠ No new data found for SWMFPO. Skipping update.
# 📌 TBBLP: Latest data in CSV is from 2016-09-14
# Scraping TBBLP - processing page 1
# Stopping further scraping for TBBLP as older data encountered.
# ⚠ No new data found for TBBLP. Skipping update.
# 📌 UAILPO: Latest data in CSV is from 2025-03-25
# Scraping UAILPO - processing page 1
# Stopping further scraping for UAILPO as older data encountered.
# ⚠ No new data found for UAILPO. Skipping update.
# 📌 UFLPO: Latest data in CSV is from 2020-10-18
# Scraping UFLPO - processing page 1
# Stopping further scraping for UFLPO as older data encountered.
# ⚠ No new data found for UFLPO. Skipping update.
# 📌 UNLBP: Latest data in CSV is from 2025-04-01
# Scraping UNLBP - processing page 1
# Stopping further scraping for UNLBP as older data encountered.
# ⚠ No new data found for UNLBP. Skipping update.
# 📌 USLBP: Latest data in CSV is from 2023-08-30
# Scraping USLBP - processing page 1
# Stopping further scraping for USLBP as older data encountered.
# ⚠ No new data found for USLBP. Skipping update.
# 📌 VLBSPO: Latest data in CSV is from 2024-12-22
# Scraping VLBSPO - processing page 1
# Stopping further scraping for VLBSPO as older data encountered.
# ⚠ No new data found for VLBSPO. Skipping update.
# Error accessing price history for WNLBP: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 0
# 📌 BBC: Latest data in CSV is from 2025-04-07
# Scraping BBC - processing page 1
# Stopping further scraping for BBC as older data encountered.
# ✅ New data added for BBC in Nepse_Data/Tradings/BBC.csv
# 0
# 0
#
#
# Error accessing price history for SEBON: Message:
# Stacktrace:
# #0 0x578ca4769e6a <unknown>
# #1 0x578ca421b640 <unknown>
# #2 0x578ca426cb5a <unknown>
# #3 0x578ca426cd51 <unknown>
# #4 0x578ca42bb344 <unknown>
# #5 0x578ca429277d <unknown>
# #6 0x578ca42b87b5 <unknown>
# #7 0x578ca4292523 <unknown>
# #8 0x578ca425eef3 <unknown>
# #9 0x578ca425fb51 <unknown>
# #10 0x578ca472ed2b <unknown>
# #11 0x578ca4732c01 <unknown>
# #12 0x578ca4716512 <unknown>
# #13 0x578ca4733774 <unknown>
# #14 0x578ca46fa90f <unknown>
# #15 0x578ca4757fb8 <unknown>
# #16 0x578ca4758196 <unknown>
# #17 0x578ca4768cb6 <unknown>
# #18 0x7a86fd5bcac3 <unknown>
#
# 📌 STC: Latest data in CSV is from 2025-04-07
# Scraping STC - processing page 1
# Stopping further scraping for STC as older data encountered.
# ✅ New data added for STC in Nepse_Data/Tradings/STC.csv
# 0
# 0
#
#
# 0

# %%
driver.quit()
print("✅ Scraping completed for all symbols.")
# Out:
# ✅ Scraping completed for all symbols.

# %%
# !git status
# !git add .
# !git commit -m "This is last Change."
# !git push origin main  # Or 'master' if needed
